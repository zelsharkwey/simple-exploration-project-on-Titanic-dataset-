# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Titanic.csv',index_col=0)

# %%
df.head()
#to explore the dataset
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                 Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892            male  34.5      0      0   330911   7.8292   NaN        Q
# 893          female  47.0      1      0   363272   7.0000   NaN        S
# 894            male  62.0      0      0   240276   9.6875   NaN        Q
# 895            male  27.0      0      0   315154   8.6625   NaN        S
# 896          female  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['FamilySize']=df.SibSp+df.Parch+1
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
m_mvalues = df['Age'].mean()

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
average_age_class = df.groupby('Pclass')['Age'].mean()
average_age_class
# Out:
# Pclass
# 1    40.022928
# 2    28.857881
# 3    26.090397
# Name: Age, dtype: float64

# %%
average_age_class.plot(kind='bar',color=['red','green','blue'])
plt.style.use('seaborn-v0_8')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 892 to 1309
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    418 non-null    int64
#  1   Pclass      418 non-null    int64
#  2   Name        418 non-null    object
#  3   Sex         418 non-null    object
#  4   Age         418 non-null    float64
#  5   SibSp       418 non-null    int64
#  6   Parch       418 non-null    int64
#  7   Ticket      418 non-null    object
#  8   Fare        417 non-null    float64
#  9   Cabin       91 non-null     object
#  10  Embarked    418 non-null    object
#  11  FamilySize  418 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  417.000000
# mean     0.363636    2.265550   30.272590    0.447368    0.392344   35.627188
# std      0.481622    0.841838   12.634534    0.896760    0.981429   55.907576
# min      0.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   30.272590    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.750000    1.000000    0.000000   31.500000
# max      1.000000    3.000000   76.000000    8.000000    9.000000  512.329200
#
#        FamilySize
# count  418.000000
# mean     1.839713
# std      1.519072
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max     11.000000

# %%
survival_series = df['Survived']
print(df['Survived'])
# Out:
# PassengerId
# 892     0
# 893     1
# 894     0
# 895     0
# 896     1
#        ..
# 1305    0
# 1306    1
# 1307    0
# 1308    0
# 1309    0
# Name: Survived, Length: 418, dtype: int64

# %%
survived_num = df.Survived.value_counts()
survived_num
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
survived_num.plot(kind = 'bar',color=['black','gray'])
plt.style.use('seaborn-v0_8')
plt.show()

# %%
survival_rate = df['Survived'].value_counts()
survival_rate
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
survival_rate.plot(kind='pie')
plt.style.use('seaborn-v0_8')
plt.show()

# %%
print(df['Pclass'])
# Out:
# PassengerId
# 892     3
# 893     3
# 894     2
# 895     3
# 896     3
#        ..
# 1305    3
# 1306    1
# 1307    3
# 1308    3
# 1309    3
# Name: Pclass, Length: 418, dtype: int64

# %%
num_of_Pclass = df.Pclass.value_counts()
num_of_Pclass
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
num_of_Pclass.plot(kind='pie')
plt.style.use('seaborn-v0_8')
plt.show()

# %%
sex = df['Sex'].value_counts()
sex
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
sex.plot(kind ='bar',color=['cyan','pink'])
plt.style.use('seaborn-v0_8')
plt.show()

# %%
age1 = df.Age.unique()
age1
# Out:
# array([34.5       , 47.        , 62.        , 27.        , 22.        ,
#        14.        , 30.        , 26.        , 18.        , 21.        ,
#        30.27259036, 46.        , 23.        , 63.        , 24.        ,
#        35.        , 45.        , 55.        ,  9.        , 48.        ,
#        50.        , 22.5       , 41.        , 33.        , 18.5       ,
#        25.        , 39.        , 60.        , 36.        , 20.        ,
#        28.        , 10.        , 17.        , 32.        , 13.        ,
#        31.        , 29.        , 28.5       , 32.5       ,  6.        ,
#        67.        , 49.        ,  2.        , 76.        , 43.        ,
#        16.        ,  1.        , 12.        , 42.        , 53.        ,
#        26.5       , 40.        , 61.        , 60.5       ,  7.        ,
#        15.        , 54.        , 64.        , 37.        , 34.        ,
#        11.5       ,  8.        ,  0.33      , 38.        , 57.        ,
# ...

# %%
age = df.Age.value_counts()
age
# Out:
# Age
# 30.27259    86
# 21.00000    17
# 24.00000    17
# 22.00000    16
# 30.00000    15
#             ..
# 44.00000     1
# 5.00000      1
# 51.00000     1
# 3.00000      1
# 38.50000     1
# Name: count, Length: 80, dtype: int64

# %%
plt.hist(df['Age'])
plt.style.use('seaborn-v0_8')
plt.show()

# %%
over30 = df[df['Age']>30][['Name','Age']]
over30.head()
#filter then select
# Out:
#                                          Name       Age
# PassengerId
# 892                          Kelly, Mr. James  34.50000
# 893          Wilkes, Mrs. James (Ellen Needs)  47.00000
# 894                 Myles, Mr. Thomas Francis  62.00000
# 902                          Ilieff, Mr. Ylio  30.27259
# 903                Jones, Mr. Charles Cresson  46.00000

# %%
over30 = df[df['Age']>30]
over30.head()
#filter then select
# Out:
#              Survived  Pclass                              Name     Sex  \
# PassengerId
# 892                 0       3                  Kelly, Mr. James    male
# 893                 1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 894                 0       2         Myles, Mr. Thomas Francis    male
# 902                 0       3                  Ilieff, Mr. Ylio    male
# 903                 0       1        Jones, Mr. Charles Cresson    male
#
#                   Age  SibSp  Parch  Ticket     Fare Cabin Embarked  \
# PassengerId
# 892          34.50000      0      0  330911   7.8292   NaN        Q
# 893          47.00000      1      0  363272   7.0000   NaN        S
# 894          62.00000      0      0  240276   9.6875   NaN        Q
# 902          30.27259      0      0  349220   7.8958   NaN        S
# 903          46.00000      0      0     694  26.0000   NaN        S
#
#              FamilySize
# PassengerId
# 892                   1
# 893                   2
# ...
